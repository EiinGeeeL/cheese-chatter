# %% [markdown]
# # VISION TRANSFORMERS (ViT) KERAS - TENSORFLOW
#
# ![image.png](attachment:image.png)

# %% [markdown]
# > https://github.com/taki0112/vit-tensorflow/blob/main/vit_tensorflow/vit_for_small_dataset.py
#
# > https://github.com/nikhilroxtomar/Vision-Transformer-ViT-in-TensorFlow/blob/main/vit.py
#
# > https://keras.io/examples/vision/image_classification_with_vision_transformer/
#
# > https://huggingface.co/learn/cookbook/en/fine_tuning_vit_custom_dataset

# %%
# NOTE: descarted due low amount of data
